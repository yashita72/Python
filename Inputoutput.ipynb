# %% [markdown]
# <a href="https://colab.research.google.com/github/yashita72/Python/blob/main/Inputoutput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Input Output in Python

# %%
name = input("Enter your name: ")#taking input
print("Hello,", name, "! Welcome!")
# Out:
# Enter your name: yashita gaur
# Hello, yashita gaur ! Welcome!

# %%
print("Hello, World!")#for output printing
# Out:
# Hello, World!

# %%
s = "Bradie" #printing variables
print(s)

s = "Anjel"
age = 25
city = "New York"
print(s, age, city)
# Out:
# Bradie
# Anjel 25 New York

# %%
x, y = input("Enter two numbers: ").split()#taking multiple inputs at a time
print(x , y)
# Out:
# Enter two numbers: 3 4
# 3 4

# %%
i = int(input("How old are you?: ")) #taking diff types of user input
f = float(input("Evaluate 7/2: "))
print(i, f)
# Out:
# How old are you?: 19
# Evaluate 7/2: 3.5
# 19 3.5
