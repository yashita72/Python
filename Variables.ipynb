# %% [markdown]
# <a href="https://colab.research.google.com/github/yashita72/Python/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5 #store
name = "Alexaa"
print(x)
print(name) #print
# Out:
# 5
# Alexaa

# %%
x = 10 #dynamic typing
x = "Now a string"

# %%
a = b = c = 100
print(a, b, c)
# Out:
# 100 100 100

# %%
x, y, z = 1, 2.5, "Python" #multiple assigning
print(x, y, z)
# Out:
# 1 2.5 Python

# %%
x = 1 # variables refer to the object 1 as a value
y = x # shared refernece concept that y and x refer to same object i.e 1
y = y + 1 # now y refers to 2 while x still refers to 1

print(x)# if no one refers to 1 then it wil be garbage value
print(y)
# Out:
# 1
# 2

# %%
x = 10 #deleting the variable
del x

# %%
a, b = 5, 10 #swapping two variables
a, b = b, a
print(a, b)
# Out:
# 10 5

# %%
word = "Python"
length = len(word) #length of word
print("Length of the word:", length)
# Out:
# Length of the word: 6
