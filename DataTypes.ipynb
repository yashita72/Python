# %%
x = 50
x = 60.5
x = "Hello World"
x = ["geeks", "for", "geeks"]
x = ("geeks", "for", "geeks")

# %%
a = 5
b = 5.0
c = 2 + 4j

print(type(a))
print(type(b))
print(type(c))

# %%
s = 'Welcome to the  World'
print(s)
print(type(s))

# access string with index
print(s[1])
print(s[-1])
